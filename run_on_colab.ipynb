# %% [markdown]
# # LLM Fine-tuning & Alignment on Free Google Colab
#
# This notebook demonstrates how to run the `llm-finetuning-pipeline` on a free T4 GPU in Google Colab.
#
# **Important**: Go to `Runtime` -> `Change runtime type` and select `T4 GPU` before starting.

# %%
# 1. Clone the repository (Assuming you push this to GitHub)
# !git clone https://github.com/your-username/llm-finetuning-pipeline.git
# %cd llm-finetuning-pipeline

# %%
# 2. Install Dependencies
# Note: Colab usually has torch pre-installed, so we just install the rest.
# !pip install transformers peft trl accelerate bitsandbytes datasets vllm lm-eval

# %%
# 3. Run Data Preparation
# !python src/data/prepare_dataset.py

# %%
# 4. Run Supervised Fine-Tuning (QLoRA)
# !python src/training/sft_trainer.py

# %%
# 5. Run Alignment (DPO)
# !python src/training/dpo_trainer.py
